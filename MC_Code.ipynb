# %%
import pandas as pd
url_player = "https://drive.google.com/uc?export=download&id=1Mw9vW0hjTJwRWx0bDXiSpYsO3gKogaPz"
url_session = "https://drive.google.com/uc?export=download&id=14O91N5OlVkvdGxXNJUj5jIsV5RexhzbB"
player_data = pd.read_csv(url_player)
session_data = pd.read_csv(url_session)
player_data
# Out:
#     experience  subscribe                                        hashedEmail  \
# 0          Pro       True  f6daba428a5e19a3d47574858c13550499be23603422e6...
# 1      Veteran       True  f3c813577c458ba0dfef80996f8f32c93b6e8af1fa9397...
# 2      Veteran      False  b674dd7ee0d24096d1c019615ce4d12b20fcbff12d79d3...
# 3      Amateur       True  23fe711e0e3b77f1da7aa221ab1192afe21648d47d2b4f...
# 4      Regular       True  7dc01f10bf20671ecfccdac23812b1b415acd42c2147cb...
# ..         ...        ...                                                ...
# 191    Amateur       True  b6e9e593b9ec51c5e335457341c324c34a2239531e1890...
# 192    Veteran      False  71453e425f07d10da4fa2b349c83e73ccdf0fb3312f778...
# 193    Amateur      False  d572f391d452b76ea2d7e5e53a3d38bfd7499c7399db29...
# 194    Amateur      False  f19e136ddde68f365afc860c725ccff54307dedd13968e...
# 195        Pro       True  d9473710057f7d42f36570f0be83817a4eea614029ff90...
#
# ...

# %% [markdown]
# Noah's Code Stuff Updated

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.neighbors import KNeighborsRegressor

player_filtered = player_data.loc[:, ["played_hours", "gender", "age"]]

mc_train, mc_test = train_test_split(
    player_filtered, train_size = 0.75
)

mc_preprocessor = make_column_transformer(
    (StandardScaler(), ["age"]),
)

mc_pipeline = make_pipeline(mc_preprocessor, KNeighborsRegressor())
param_grid = {
    "kneighborsregressor__n_neighbors":range(1,201,3),
}

mc_gridsearch = GridSearchCV(
    estimator = mc_pipeline,
    param_grid = param_grid,
    cv = 5,
    scoring = "neg_root_mean_squared_error",
    n_jobs = -1
)
mc_gridsearch.fit(
    mc_train[["age"]],
    mc_train["played_hours"]
)
mc_results = pd.DataFrame(mc_gridsearch.cv_results_)
mc_results
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:982: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 971, in _score
#     scores = scorer(estimator, X_test, y_test, **score_params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 279, in __call__
#     return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/lib/python3.11/site-packages/sklearn/metrics/_scorer.py", line 371, in _score
#     y_pred = method_caller(
#              ^^^^^^^^^^^^^^
# ...

# %%
mc_results["mean_test_score"] = -mc_results["mean_test_score"]
mc_results
mc_gridsearch.best_params_
# Out:
# {'kneighborsregressor__n_neighbors': 115}
